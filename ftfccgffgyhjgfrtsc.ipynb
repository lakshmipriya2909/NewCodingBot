# %%
from IPython.display import HTML

html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Online Resume Builder</title>
</head>
<body>
    <header>
        <h1>Resume Builder</h1>
    </header>
    <section id="resume-form">
        <h2>Create Your Resume</h2>
        <form id="resume">
            <label for="name">Name:</label>
            <input type="text" id="name" name="name" required><br><br>

            <label for="email">Email:</label>
            <input type="email" id="email" name="email" required><br><br>

            <label for="education">Education:</label>
            <textarea id="education" name="education" rows="4" cols="50" required></textarea><br><br>

            <label for="experience">Work Experience:</label>
            <textarea id="experience" name="experience" rows="4" cols="50" required></textarea><br><br>

            <label for="skills">Skills:</label>
            <textarea id="skills" name="skills" rows="4" cols="50" required></textarea><br><br>

            <button type="button" id="preview-btn">Preview</button>
            <button type="button" id="download-btn">Download</button>
        </form>
    </section>

    <section id="resume-preview">
        <h2>Resume Preview</h2>
        <div id="preview-content"></div>
    </section>

    <script>
        const resumeForm = document.getElementById("resume");
        const previewBtn = document.getElementById("preview-btn");
        const downloadBtn = document.getElementById("download-btn");
        const previewContent = document.getElementById("preview-content");

        previewBtn.addEventListener("click", function () {
            const formData = new FormData(resumeForm);

            let html = "<h3>Personal Info</h3>";
            html += `<p><strong>Name:</strong> ${formData.get("name")}</p>`;
            html += `<p><strong>Email:</strong> ${formData.get("email")}</p>`;

            html += "<h3>Education</h3>";
            html += `<p>${formData.get("education")}</p>`;

            html += "<h3>Work Experience</h3>";
            html += `<p>${formData.get("experience")}</p>`;

            html += "<h3>Skills</h3>";
            html += `<p>${formData.get("skills")}</p>`;

            previewContent.innerHTML = html;
        });

        downloadBtn.addEventListener("click", function () {
            // You can implement the code to generate and download a PDF here
        });
    </script>
</body>
</html>
"""

# Open the HTML content in a new browser window or tab
display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Online Resume Builder</title>
# </head>
# <body>
#     <header>
#         <h1>Resume Builder</h1>
#     </header>
#     <section id="resume-form">
#         <h2>Create Your Resume</h2>
#         <form id="resume">
#             <label for="name">Name:</label>
#             <input type="text" id="name" name="name" required><br><br>
#
#             <label for="email">Email:</label>
#             <input type="email" id="email" name="email" required><br><br>
#
#             <label for="education">Education:</label>
#             <textarea id="education" name="education" rows="4" cols="50" required></textarea><br><br>
#
#             <label for="experience">Work Experience:</label>
#             <textarea id="experience" name="experience" rows="4" cols="50" required></textarea><br><br>
#
# ...
